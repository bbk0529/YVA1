# %%
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
# %matplotlib inline

# %%
items=[]
item=[]
toggle=False

with open('text.txt',"r", encoding="UTF-8") as file:
    line=file.readline()
    while line.find('*****')<0:
        line=file.readline()
        if line[0]=='-' and toggle==False:
            toggle=True
            continue
    
        if toggle==True:
            if line[0]=='|' : 
                
                item.append(list(map(str.strip, line[:-1].split("|"))))
                continue
            
            if line[0]=='-' :
                #toggle=False
                if len(item)>0 : 
                    items.append(item)
                    print(item)
                    item=[]
                continue
            else :
                toggle=False
                continue
# Out:
# [['', 'Item / M.', 'RR', 'MATERIAL', 'Description', 'Bi.bl', 'Rea', 'Cat In.no.+Status', 'PS', '', 'Di', '', '', 'S', 'L', 'T', ''], ['', 'CUSR.ITEM', 'Cust.mat.no.', 'Plan Sloc', 'TD', '', '']]
# [['', '10', '', '574090', 'electric drive  ESBF-...-63-150', '', '', 'X2  1374107355   ERO', 'KC', '01', '', '', '00', '00', '000', ''], ['', '1', '000000000000574090', '0015', '300', '', ''], ['', '', '02-19-18     6', '2018454054  03-27-18     6', '', '', '']]
# [['', '20', '', '8024917', 'Toothed b. axis ELGA-TB-KF-150-2900', '', '', 'O2  1374107354   LOE', 'KS', '01', '', '', '00', '00', '000', ''], ['', '2', '000000000008024917', '0015', '300', '', ''], ['', '', '02-19-18     1', '2018454054  03-13-18     1', '28 0001 1776852297/20   03-09-18     1', '20906945/10   03-09-18     1', '']]
# [['', '30', '', '556809', 'Spindle axis    EGC-120-220-BS-KF', '', '', 'O2  1374107297   GLFT', 'KC', '01', '', '', '00', '00', '000', ''], ['', '3', '000000000000556809', '0015', '300', '', ''], ['', '', '02-19-18     1', '2018454054  03-13-18     1', '28 0001 1776852297/30   NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1776967817/30   NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1776996691/30   NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777007557/30   NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777050459/30   NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777068402/30   NOT DELIVERED', '', ''], ['', '', '', '', 'stored in  :          1 fr. 03-13-18', '', '']]
# [['', '40', '', '556815', 'Toothed b. axis EGC-120-940-TB-KF', '', '', 'O2  1374107225   LOE', 'KS', '01', '', '', '00', '00', '000', ''], ['', '4', '000000000000556815', '0015', '300', '', ''], ['', '', '02-19-18     1', '2018454054  03-13-18     1', '28 0001 1776852297/40   NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1776967817/40   03-12-18     1', '20907778/100  03-12-18     1', '']]
# [['', '50', '', '556815', 'Toothed b. axis EGC-120-1440-TB-KF', '', '', 'O2  1374107236   GLFT', 'KS', '01', '', '', '00', '00', '000', ''], ['', '5', '000000000000556815', '0015', '300', '', ''], ['', '', '02-19-18     1', '2018454054  03-13-18     1', '28 0001 1776852297/50   NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1776967817/50   NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1776996691/50   NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777007557/50   03-13-18     1', '20908611/180  03-13-18     1', '']]
# [['', '60', '', '556815', 'Toothed b. axis EGC-120-1540-TB-KF', '', '', 'O2  1374107269   GLFT', 'KS', '01', '', '', '00', '00', '000', ''], ['', '6', '000000000000556815', '0015', '300', '', ''], ['', '', '02-19-18     2', '2018454054  03-13-18     2', '28 0001 1776852297/60   NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1776967817/60   NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1776996691/60   NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777007557/60   NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777050459/60   NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777068402/60   NOT DELIVERED', '', ''], ['', '', '', '', 'stored in  :          2 fr. 03-12-18', '', '']]
# [['', '70', '', '556815', 'Toothed b. axis EGC-120-1040-TB-KF', '', '', 'O2  1374107280   GLFT', 'KS', '01', '', '', '00', '00', '000', ''], ['', '7', '000000000000556815', '0015', '300', '', ''], ['', '', '02-19-18     1', '2018454054  03-13-18     1', '28 0001 1776852297/70   NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1776967817/70   NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1776996691/70   NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777007557/70   NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777050459/70   NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777068402/70   NOT DELIVERED', '', ''], ['', '', '', '', 'stored in  :          1 fr. 03-12-18', '', '']]
# [['', '80', '', '556815', 'Toothed b. axis EGC-120-2040-TB-KF', '', '', 'O2  1374107292   TRÜC', 'KS', '01', '', '', '00', '00', '000', ''], ['', '8', '000000000000556815', '0015', '300', '', ''], ['', '', '02-19-18     1', '2018454054  03-13-18     1', '28 0001 1776852297/80   NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1776967817/80   NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1776996691/80   NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777007557/80   NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777050459/80   NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777068402/80   NOT DELIVERED', '', '']]
# [['', '90', '', '556815', 'Toothed b. axis EGC-120-1540-TB-KF', '', '', 'O2  1374107304   GLFT', 'KS', '01', '', '', '00', '00', '000', ''], ['', '9', '000000000000556815', '0015', '300', '', ''], ['', '', '02-19-18     2', '2018454054  03-13-18     2', '28 0001 1776852297/90   NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1776967817/90   NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1776996691/90   03-13-18     2', '20908611/130  03-13-18     2', '']]
# [['', '100', '', '556815', 'Toothed b. axis EGC-120-2440-TB-KF', '', '', 'O2  1374107315   RÜCK', 'KS', '01', '', '', '00', '00', '000', ''], ['', '10', '000000000000556815', '0015', '300', '', ''], ['', '', '02-19-18     2', '2018454054  03-13-18     2', '28 0001 1776852297/100  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1776967817/100  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1776996691/100  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777007557/100  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777050459/100  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777068402/100  NOT DELIVERED', '', '']]
# [['', '110', '', '556815', 'Toothed b. axis EGC-120-2120-TB-KF', '', '', 'O2  1374107214   TRÜC', 'KS', '01', '', '', '00', '00', '000', ''], ['', '11', '000000000000556815', '0015', '300', '', ''], ['', '', '02-19-18     4', '2018454054  03-13-18     4', '28 0001 1776852297/110  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1776967817/110  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1776996691/110  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777007557/110  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777050459/110  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777068402/110  NOT DELIVERED', '', '']]
# [['', '120', '', '556815', 'Toothed b. axis EGC-120-1200-TB-KF', '', '', 'O2  1374107346   GLFT', 'KS', '01', '', '', '00', '00', '000', ''], ['', '12', '000000000000556815', '0015', '300', '', ''], ['', '', '02-19-18     2', '2018454054  03-13-18     2', '28 0001 1776852297/120  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1776967817/120  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1776996691/120  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777007557/120  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777050459/120  03-15-18     2', '20910355/30   03-15-18     2', '']]
# [['', '130', '', '556815', 'Toothed b. axis EGC-120-1600-TB-KF', '', '', 'O2  1374107361   GLFT', 'KS', '01', '', '', '00', '00', '000', ''], ['', '13', '000000000000556815', '0015', '300', '', ''], ['', '', '02-19-18     2', '2018454054  03-13-18     2', '28 0001 1776852297/130  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1776967817/130  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1776996691/130  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777007557/130  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777050459/130  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777068402/130  03-15-18     2', '20910375/170  03-15-18     2', '']]
# [['', '140', '', '556820', 'Spindle axis    EGC-HD-160-    -BS', '', '', 'O2  1374107352   ERO', 'KC', '01', '', '', '00', '00', '000', ''], ['', '14', '000000000000556820', '0015', '300', '', ''], ['', '', '02-19-18     2', '2018454054  04-05-18     2', '', '', '']]
# [['', '150', '', '556821', 'Spindle axis    EGC-HD-220-    -BS', '', '', 'O2  1374107427   ERO', 'KC', '01', '', '', '00', '00', '000', ''], ['', '15', '000000000000556821', '0015', '300', '', ''], ['', '', '02-19-18     1', '2018454054  03-27-18     1', '', '', '']]
# [['', '160', '', '556821', 'Spindle axis    EGC-HD-220-    -BS', '', '', 'O2  1374106338   GLFT', 'KC', '01', '', '', '00', '00', '000', ''], ['', '16', '000000000000556821', '0015', '300', '', ''], ['', '', '02-19-18    11', '2018454054  03-13-18     5      M2', '28 0001 1776852297/160  NOT DELIVERED', '', ''], ['', '', '', '2018454054  03-14-18     3', '28 0001 1776967817/160  NOT DELIVERED', '', ''], ['', '', '', '2018454054  03-15-18     3', '28 0001 1776996691/160  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777007557/160  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777050459/160  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777068402/160  NOT DELIVERED', '', ''], ['', '', '', '', 'stored in  :          2 fr. 03-12-18', '', '']]
# [['', '170', '', '556825', 'Toothed b. axis EGC-HD-220-    -TB', '', '', 'O2  1374106329   GLFT', 'KC', '01', '', '', '00', '00', '000', ''], ['', '17', '000000000000556825', '0015', '300', '', ''], ['', '', '02-19-18     5', '2018454054  03-13-18     3      M2', '28 0001 1776852297/170  NOT DELIVERED', '', ''], ['', '', '', '2018454054  03-14-18     2', '28 0001 1776967817/170  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1776996691/170  03-13-18     5', '20908611/140  03-13-18     5', '']]
# [['', '180', '', '556825', 'Toothed b. axis EGC-HD-220-    -TB', '', '', 'O2  1374141586   ERO', 'KC', '01', '', '', '00', '00', '000', ''], ['', '18', '000000000000556825', '0015', '300', '', ''], ['', '', '02-19-18     1', '2018454054  03-20-18     1', '28 0001 1776996691/180  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777007557/180  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777050459/180  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777068402/180  NOT DELIVERED', '', '']]
# [['', '190', '', '556825', 'Toothed b. axis EGC-HD-220-    -TB', '', '', 'O2  1374141593   ERO', 'KC', '01', '', '', '00', '00', '000', ''], ['', '19', '000000000000556825', '0015', '300', '', ''], ['', '', '02-19-18     1', '2018454054  03-20-18     1', '28 0001 1776996691/190  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777007557/190  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777050459/190  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777068402/190  NOT DELIVERED', '', '']]
# [['', '200', '', '556825', 'Toothed b. axis EGC-HD-220-    -TB', '', '', 'O2  1374141620   ERO', 'KC', '01', '', '', '00', '00', '000', ''], ['', '20', '000000000000556825', '0015', '300', '', ''], ['', '', '02-19-18     1', '2018454054  03-20-18     1', '28 0001 1776996691/200  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777007557/200  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777050459/200  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777068402/200  NOT DELIVERED', '', '']]
# [['', '210', '', '556825', 'Toothed b. axis EGC-HD-220-    -TB', '', '', 'O2  1374141628   ERO', 'KC', '01', '', '', '00', '00', '000', ''], ['', '21', '000000000000556825', '0015', '300', '', ''], ['', '', '02-19-18     1', '2018454054  03-20-18     1', '28 0001 1776996691/210  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777007557/210  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777050459/210  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777068402/210  NOT DELIVERED', '', '']]
# [['', '220', '', '556825', 'Toothed b. axis EGC-HD-220-    -TB', '', '', 'O2  1374141635   ERO', 'KC', '01', '', '', '00', '00', '000', ''], ['', '22', '000000000000556825', '0015', '300', '', ''], ['', '', '02-19-18     2', '2018454054  03-20-18     2', '28 0001 1776996691/220  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777007557/220  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777050459/220  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777068402/220  NOT DELIVERED', '', '']]
# [['', '230', '', '556825', 'Toothed b. axis EGC-HD-220-    -TB', '', '', 'O2  1374141642   ERO', 'KC', '01', '', '', '00', '00', '000', ''], ['', '23', '000000000000556825', '0015', '300', '', ''], ['', '', '02-19-18     1', '2018454054  03-20-18     1', '28 0001 1776996691/230  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777007557/230  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777050459/230  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777068402/230  NOT DELIVERED', '', '']]
# [['', '240', '', '556825', 'Toothed b. axis EGC-HD-220-    -TB', '', '', 'O2  1374141648   ERO', 'KC', '01', '', '', '00', '00', '000', ''], ['', '24', '000000000000556825', '0015', '300', '', ''], ['', '', '02-19-18     1', '2018454054  03-20-18     1', '28 0001 1776996691/240  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777007557/240  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777050459/240  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777068402/240  NOT DELIVERED', '', '']]
# [['', '250', '', '556825', 'Toothed b. axis EGC-HD-220-    -TB', '', '', 'O2  1374141655   ERO', 'KC', '01', '', '', '00', '00', '000', ''], ['', '25', '000000000000556825', '0015', '300', '', ''], ['', '', '02-19-18     1', '2018454054  03-20-18     1', '28 0001 1776996691/250  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777007557/250  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777050459/250  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777068402/250  NOT DELIVERED', '', '']]
# [['', '260', '', '556825', 'Toothed b. axis EGC-HD-220-    -TB', '', '', 'O2  1374141662   ERO', 'KC', '01', '', '', '00', '00', '000', ''], ['', '26', '000000000000556825', '0015', '300', '', ''], ['', '', '02-19-18     1', '2018454054  03-20-18     1', '28 0001 1776996691/260  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777007557/260  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777050459/260  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777068402/260  NOT DELIVERED', '', '']]
# [['', '270', '', '556825', 'Toothed b. axis EGC-HD-220-    -TB', '', '', 'O2  1374141708   ERO', 'KC', '01', '', '', '00', '00', '000', ''], ['', '27', '000000000000556825', '0015', '300', '', ''], ['', '', '02-19-18     1', '2018454054  03-20-18     1', '28 0001 1776996691/270  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777007557/270  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777050459/270  NOT DELIVERED', '', ''], ['', '', '', '', '28 0001 1777068402/270  NOT DELIVERED', '', '']]
# [['', '280', '', '574100', 'electric drive  ESBF-BS-63-100-25P', '', '', '', 'CF', '01', '', '', '00', '00', '000', ''], ['', '28', '000000000000574100', '0015', '300', '', ''], ['', '', '03-02-18     2', '2018454054  03-02-18     2', '28 0001 1776667539/280  02-23-18     2', '20898555/150  02-23-18     2', '']]
# [['', '290', '', '574102', 'electric drive  ESBF-BS-63-300-25P', '', '', '', 'CF', '01', '', '', '00', '00', '000', ''], ['', '29', '000000000000574102', '0015', '300', '', ''], ['', '', '03-02-18    21', '2018454054  03-02-18    10      M2', '28 0001 1776667539/290  02-23-18    10', '20898555/160  02-23-18    10', ''], ['', '', '', '2018454054  03-16-18    11', '28 0001 1777000816/290  03-13-18    11', '20908611/160  03-13-18    11', '']]
# [['', '300', '', '574114', 'electric drive  ESBF-BS-80-400-32P', '', '', '', 'C', '01', '', '', '00', '00', '000', ''], ['', '30', '000000000000574114', '0015', '300', '', ''], ['', '', '03-02-18     1', '2018454054  03-02-18     1', '28 0001 1776667539/300  02-23-18     1', '20898555/170  02-23-18     1', '']]

# %%
items=[]
item=[]
toggle=False

with open('text.txt',"r", encoding="UTF-8") as file:
    line=file.readline()
    while line.find('*****')<0:
        line=file.readline()
        if line[0]=='-' and toggle==False:
            toggle=True
            continue
    
        if toggle==True:
            if line[0]=='|' : 
                item.append(list(map(str.strip, line[:-1].split("|"))))
                continue
            
            if line.count('Ident-code') :    
                print(line)
                item.append(line)
                items.append(item)
                toggle=False
                item=[]
                continue
            
            else :
                toggle=False
                continue
# Out:
#           |Ident-code              |EGC-HD-220-350-BS-25P-0H-GP                                                   |

# %%
items
# Out:
# [[['',
#    'Item / M.',
#    'RR',
#    'MATERIAL',
#    'Description',
#    'Bi.bl',
#    'Rea',
#    'Cat In.no.+Status',
#    'PS',
#    '',
#    'Di',
#    '',
#    '',
#    'S',
#    'L',
#    'T',
#    ''],
#   ['', 'CUSR.ITEM', 'Cust.mat.no.', 'Plan Sloc', 'TD', '', ''],
#   ['',
#    '10',
#    '',
#    '574090',
#    'electric drive  ESBF-...-63-150',
#    '',
#    '',
#    'X2  1374107355   ERO',
#    'KC',
#    '01',
#    '',
#    '',
#    '00',
#    '00',
#    '000',
#    ''],
#   ['', '1', '000000000000574090', '0015', '300', '', ''],
#   ['', '', '02-19-18     6', '2018454054  03-27-18     6', '', '', ''],
#   ['',
#    '20',
#    '',
#    '8024917',
#    'Toothed b. axis ELGA-TB-KF-150-2900',
#    '',
#    '',
#    'O2  1374107354   LOE',
#    'KS',
#    '01',
#    '',
#    '',
#    '00',
#    '00',
#    '000',
#    ''],
#   ['', '2', '000000000008024917', '0015', '300', '', ''],
#   ['',
#    '',
#    '02-19-18     1',
#    '2018454054  03-13-18     1',
#    '28 0001 1776852297/20   03-09-18     1',
#    '20906945/10   03-09-18     1',
#    ''],
#   ['',
#    '30',
#    '',
#    '556809',
#    'Spindle axis    EGC-120-220-BS-KF',
#    '',
#    '',
#    'O2  1374107297   GLFT',
#    'KC',
#    '01',
#    '',
#    '',
#    '00',
#    '00',
#    '000',
#    ''],
#   ['', '3', '000000000000556809', '0015', '300', '', ''],
#   ['',
#    '',
#    '02-19-18     1',
#    '2018454054  03-13-18     1',
#    '28 0001 1776852297/30   NOT DELIVERED',
#    '',
#    ''],
#   ['', '', '', '', '28 0001 1776967817/30   NOT DELIVERED', '', ''],
#   ['', '', '', '', '28 0001 1776996691/30   NOT DELIVERED', '', ''],
#   ['', '', '', '', '28 0001 1777007557/30   NOT DELIVERED', '', ''],
#   ['', '', '', '', '28 0001 1777050459/30   NOT DELIVERED', '', ''],
#   ['', '', '', '', '28 0001 1777068402/30   NOT DELIVERED', '', ''],
#   ['', '', '', '', 'stored in  :          1 fr. 03-13-18', '', ''],
#   ['',
#    '50',
#    '',
#    '556815',
#    'Toothed b. axis EGC-120-1440-TB-KF',
#    '',
#    '',
#    'O2  1374107236   GLFT',
#    'KS',
#    '01',
#    '',
#    '',
#    '00',
#    '00',
#    '000',
#    ''],
#   ['', '5', '000000000000556815', '0015', '300', '', ''],
#   ['',
#    '',
#    '02-19-18     1',
#    '2018454054  03-13-18     1',
#    '28 0001 1776852297/50   NOT DELIVERED',
#    '',
#    ''],
#   ['', '', '', '', '28 0001 1776967817/50   NOT DELIVERED', '', ''],
#   ['', '', '', '', '28 0001 1776996691/50   NOT DELIVERED', '', ''],
#   ['',
#    '',
#    '',
#    '',
#    '28 0001 1777007557/50   03-13-18     1',
#    '20908611/180  03-13-18     1',
#    ''],
#   ['',
#    '60',
#    '',
#    '556815',
#    'Toothed b. axis EGC-120-1540-TB-KF',
#    '',
#    '',
#    'O2  1374107269   GLFT',
#    'KS',
#    '01',
#    '',
#    '',
#    '00',
#    '00',
#    '000',
#    ''],
#   ['', '6', '000000000000556815', '0015', '300', '', ''],
#   ['',
#    '',
#    '02-19-18     2',
#    '2018454054  03-13-18     2',
#    '28 0001 1776852297/60   NOT DELIVERED',
#    '',
#    ''],
#   ['', '', '', '', '28 0001 1776967817/60   NOT DELIVERED', '', ''],
#   ['', '', '', '', '28 0001 1776996691/60   NOT DELIVERED', '', ''],
#   ['', '', '', '', '28 0001 1777007557/60   NOT DELIVERED', '', ''],
#   ['', '', '', '', '28 0001 1777050459/60   NOT DELIVERED', '', ''],
#   ['', '', '', '', '28 0001 1777068402/60   NOT DELIVERED', '', ''],
#   ['', '', '', '', 'stored in  :          2 fr. 03-12-18', '', ''],
#   ['',
#    '70',
#    '',
#    '556815',
#    'Toothed b. axis EGC-120-1040-TB-KF',
#    '',
#    '',
#    'O2  1374107280   GLFT',
#    'KS',
#    '01',
#    '',
#    '',
#    '00',
#    '00',
#    '000',
#    ''],
#   ['', '7', '000000000000556815', '0015', '300', '', ''],
#   ['',
#    '',
#    '02-19-18     1',
#    '2018454054  03-13-18     1',
#    '28 0001 1776852297/70   NOT DELIVERED',
#    '',
#    ''],
#   ['', '', '', '', '28 0001 1776967817/70   NOT DELIVERED', '', ''],
#   ['', '', '', '', '28 0001 1776996691/70   NOT DELIVERED', '', ''],
#   ['', '', '', '', '28 0001 1777007557/70   NOT DELIVERED', '', ''],
#   ['', '', '', '', '28 0001 1777050459/70   NOT DELIVERED', '', ''],
#   ['', '', '', '', '28 0001 1777068402/70   NOT DELIVERED', '', ''],
#   ['', '', '', '', 'stored in  :          1 fr. 03-12-18', '', ''],
#   ['',
#    '80',
#    '',
#    '556815',
#    'Toothed b. axis EGC-120-2040-TB-KF',
#    '',
#    '',
#    'O2  1374107292   TRÜC',
#    'KS',
#    '01',
#    '',
#    '',
#    '00',
#    '00',
#    '000',
#    ''],
#   ['', '8', '000000000000556815', '0015', '300', '', ''],
#   ['',
#    '',
#    '02-19-18     1',
#    '2018454054  03-13-18     1',
#    '28 0001 1776852297/80   NOT DELIVERED',
#    '',
#    ''],
#   ['', '', '', '', '28 0001 1776967817/80   NOT DELIVERED', '', ''],
#   ['', '', '', '', '28 0001 1776996691/80   NOT DELIVERED', '', ''],
#   ['', '', '', '', '28 0001 1777007557/80   NOT DELIVERED', '', ''],
#   ['', '', '', '', '28 0001 1777050459/80   NOT DELIVERED', '', ''],
#   ['', '', '', '', '28 0001 1777068402/80   NOT DELIVERED', '', ''],
#   ['',
#    '90',
#    '',
#    '556815',
#    'Toothed b. axis EGC-120-1540-TB-KF',
#    '',
#    '',
#    'O2  1374107304   GLFT',
#    'KS',
#    '01',
#    '',
#    '',
#    '00',
#    '00',
#    '000',
#    ''],
#   ['', '9', '000000000000556815', '0015', '300', '', ''],
#   ['',
#    '',
#    '02-19-18     2',
#    '2018454054  03-13-18     2',
#    '28 0001 1776852297/90   NOT DELIVERED',
#    '',
#    ''],
#   ['', '', '', '', '28 0001 1776967817/90   NOT DELIVERED', '', ''],
#   ['',
#    '',
#    '',
#    '',
#    '28 0001 1776996691/90   03-13-18     2',
#    '20908611/130  03-13-18     2',
#    ''],
#   ['',
#    '100',
#    '',
#    '556815',
#    'Toothed b. axis EGC-120-2440-TB-KF',
#    '',
#    '',
#    'O2  1374107315   RÜCK',
#    'KS',
#    '01',
#    '',
#    '',
#    '00',
#    '00',
#    '000',
#    ''],
#   ['', '10', '000000000000556815', '0015', '300', '', ''],
#   ['',
#    '',
#    '02-19-18     2',
#    '2018454054  03-13-18     2',
#    '28 0001 1776852297/100  NOT DELIVERED',
#    '',
#    ''],
#   ['', '', '', '', '28 0001 1776967817/100  NOT DELIVERED', '', ''],
#   ['', '', '', '', '28 0001 1776996691/100  NOT DELIVERED', '', ''],
#   ['', '', '', '', '28 0001 1777007557/100  NOT DELIVERED', '', ''],
#   ['', '', '', '', '28 0001 1777050459/100  NOT DELIVERED', '', ''],
#   ['', '', '', '', '28 0001 1777068402/100  NOT DELIVERED', '', ''],
#   ['',
#    '110',
#    '',
#    '556815',
#    'Toothed b. axis EGC-120-2120-TB-KF',
#    '',
#    '',
#    'O2  1374107214   TRÜC',
#    'KS',
#    '01',
#    '',
#    '',
#    '00',
#    '00',
#    '000',
#    ''],
#   ['', '11', '000000000000556815', '0015', '300', '', ''],
#   ['',
#    '',
#    '02-19-18     4',
#    '2018454054  03-13-18     4',
#    '28 0001 1776852297/110  NOT DELIVERED',
#    '',
#    ''],
#   ['', '', '', '', '28 0001 1776967817/110  NOT DELIVERED', '', ''],
#   ['', '', '', '', '28 0001 1776996691/110  NOT DELIVERED', '', ''],
#   ['', '', '', '', '28 0001 1777007557/110  NOT DELIVERED', '', ''],
#   ['', '', '', '', '28 0001 1777050459/110  NOT DELIVERED', '', ''],
#   ['', '', '', '', '28 0001 1777068402/110  NOT DELIVERED', '', ''],
#   ['',
#    '130',
#    '',
#    '556815',
#    'Toothed b. axis EGC-120-1600-TB-KF',
#    '',
#    '',
#    'O2  1374107361   GLFT',
#    'KS',
#    '01',
#    '',
#    '',
#    '00',
#    '00',
#    '000',
#    ''],
#   ['', '13', '000000000000556815', '0015', '300', '', ''],
#   ['',
#    '',
#    '02-19-18     2',
#    '2018454054  03-13-18     2',
#    '28 0001 1776852297/130  NOT DELIVERED',
#    '',
#    ''],
#   ['', '', '', '', '28 0001 1776967817/130  NOT DELIVERED', '', ''],
#   ['', '', '', '', '28 0001 1776996691/130  NOT DELIVERED', '', ''],
#   ['', '', '', '', '28 0001 1777007557/130  NOT DELIVERED', '', ''],
#   ['', '', '', '', '28 0001 1777050459/130  NOT DELIVERED', '', ''],
#   ['',
#    '',
#    '',
#    '',
#    '28 0001 1777068402/130  03-15-18     2',
#    '20910375/170  03-15-18     2',
#    ''],
#   ['',
#    '140',
#    '',
#    '556820',
#    'Spindle axis    EGC-HD-160-    -BS',
#    '',
#    '',
#    'O2  1374107352   ERO',
#    'KC',
#    '01',
#    '',
#    '',
#    '00',
#    '00',
#    '000',
#    ''],
#   ['', '14', '000000000000556820', '0015', '300', '', ''],
#   ['', '', '02-19-18     2', '2018454054  04-05-18     2', '', '', ''],
#   ['',
#    '150',
#    '',
#    '556821',
#    'Spindle axis    EGC-HD-220-    -BS',
#    '',
#    '',
#    'O2  1374107427   ERO',
#    'KC',
#    '01',
#    '',
#    '',
#    '00',
#    '00',
#    '000',
#    ''],
#   ['', '15', '000000000000556821', '0015', '300', '', ''],
#   ['', '', '02-19-18     1', '2018454054  03-27-18     1', '', '', ''],
#   ['',
#    '160',
#    '',
#    '556821',
#    'Spindle axis    EGC-HD-220-    -BS',
#    '',
#    '',
#    'O2  1374106338   GLFT',
#    'KC',
#    '01',
#    '',
#    '',
#    '00',
#    '00',
#    '000',
#    ''],
#   ['', '16', '000000000000556821', '0015', '300', '', ''],
#   ['',
#    '',
#    '02-19-18    11',
#    '2018454054  03-13-18     5      M2',
#    '28 0001 1776852297/160  NOT DELIVERED',
#    '',
#    ''],
#   ['',
#    '',
#    '',
#    '2018454054  03-14-18     3',
#    '28 0001 1776967817/160  NOT DELIVERED',
#    '',
#    ''],
#   ['',
#    '',
#    '',
#    '2018454054  03-15-18     3',
#    '28 0001 1776996691/160  NOT DELIVERED',
#    '',
#    ''],
#   ['', '', '', '', '28 0001 1777007557/160  NOT DELIVERED', '', ''],
#   ['', '', '', '', '28 0001 1777050459/160  NOT DELIVERED', '', ''],
#   ['', '', '', '', '28 0001 1777068402/160  NOT DELIVERED', '', ''],
#   ['', '', '', '', 'stored in  :          2 fr. 03-12-18', '', ''],
#   '          |Ident-code              |EGC-HD-220-350-BS-25P-0H-GP                                                   |\n']]

# %%
items[0]
# Out:
# [['',
#   'Item / M.',
#   'RR',
#   'MATERIAL',
#   'Description',
#   'Bi.bl',
#   'Rea',
#   'Cat In.no.+Status',
#   'PS',
#   '',
#   'Di',
#   '',
#   '',
#   'S',
#   'L',
#   'T',
#   ''],
#  ['', 'CUSR.ITEM', 'Cust.mat.no.', 'Plan Sloc', 'TD', '', ''],
#  ['',
#   '10',
#   '',
#   '574090',
#   'electric drive  ESBF-...-63-150',
#   '',
#   '',
#   'X2  1374107355   ERO',
#   'KC',
#   '01',
#   '',
#   '',
#   '00',
#   '00',
#   '000',
#   ''],
#  ['', '1', '000000000000574090', '0015', '300', '', ''],
#  ['', '', '02-19-18     6', '2018454054  03-27-18     6', '', '', ''],
#  ['',
#   '20',
#   '',
#   '8024917',
#   'Toothed b. axis ELGA-TB-KF-150-2900',
#   '',
#   '',
#   'O2  1374107354   LOE',
#   'KS',
#   '01',
#   '',
#   '',
#   '00',
#   '00',
#   '000',
#   ''],
#  ['', '2', '000000000008024917', '0015', '300', '', ''],
#  ['',
#   '',
#   '02-19-18     1',
#   '2018454054  03-13-18     1',
#   '28 0001 1776852297/20   03-09-18     1',
#   '20906945/10   03-09-18     1',
#   ''],
#  ['',
#   '30',
#   '',
#   '556809',
#   'Spindle axis    EGC-120-220-BS-KF',
#   '',
#   '',
#   'O2  1374107297   GLFT',
#   'KC',
#   '01',
#   '',
#   '',
#   '00',
#   '00',
#   '000',
#   ''],
#  ['', '3', '000000000000556809', '0015', '300', '', ''],
#  ['',
#   '',
#   '02-19-18     1',
#   '2018454054  03-13-18     1',
#   '28 0001 1776852297/30   NOT DELIVERED',
#   '',
#   ''],
#  ['', '', '', '', '28 0001 1776967817/30   NOT DELIVERED', '', ''],
#  ['', '', '', '', '28 0001 1776996691/30   NOT DELIVERED', '', ''],
#  ['', '', '', '', '28 0001 1777007557/30   NOT DELIVERED', '', ''],
#  ['', '', '', '', '28 0001 1777050459/30   NOT DELIVERED', '', ''],
#  ['', '', '', '', '28 0001 1777068402/30   NOT DELIVERED', '', ''],
#  ['', '', '', '', 'stored in  :          1 fr. 03-13-18', '', ''],
#  ['',
#   '50',
#   '',
#   '556815',
#   'Toothed b. axis EGC-120-1440-TB-KF',
#   '',
#   '',
#   'O2  1374107236   GLFT',
#   'KS',
#   '01',
#   '',
#   '',
#   '00',
#   '00',
#   '000',
#   ''],
#  ['', '5', '000000000000556815', '0015', '300', '', ''],
#  ['',
#   '',
#   '02-19-18     1',
#   '2018454054  03-13-18     1',
#   '28 0001 1776852297/50   NOT DELIVERED',
#   '',
#   ''],
#  ['', '', '', '', '28 0001 1776967817/50   NOT DELIVERED', '', ''],
#  ['', '', '', '', '28 0001 1776996691/50   NOT DELIVERED', '', ''],
#  ['',
#   '',
#   '',
#   '',
#   '28 0001 1777007557/50   03-13-18     1',
#   '20908611/180  03-13-18     1',
#   ''],
#  ['',
#   '60',
#   '',
#   '556815',
#   'Toothed b. axis EGC-120-1540-TB-KF',
#   '',
#   '',
#   'O2  1374107269   GLFT',
#   'KS',
#   '01',
#   '',
#   '',
#   '00',
#   '00',
#   '000',
#   ''],
#  ['', '6', '000000000000556815', '0015', '300', '', ''],
#  ['',
#   '',
#   '02-19-18     2',
#   '2018454054  03-13-18     2',
#   '28 0001 1776852297/60   NOT DELIVERED',
#   '',
#   ''],
#  ['', '', '', '', '28 0001 1776967817/60   NOT DELIVERED', '', ''],
#  ['', '', '', '', '28 0001 1776996691/60   NOT DELIVERED', '', ''],
#  ['', '', '', '', '28 0001 1777007557/60   NOT DELIVERED', '', ''],
#  ['', '', '', '', '28 0001 1777050459/60   NOT DELIVERED', '', ''],
#  ['', '', '', '', '28 0001 1777068402/60   NOT DELIVERED', '', ''],
#  ['', '', '', '', 'stored in  :          2 fr. 03-12-18', '', ''],
#  ['',
#   '70',
#   '',
#   '556815',
#   'Toothed b. axis EGC-120-1040-TB-KF',
#   '',
#   '',
#   'O2  1374107280   GLFT',
#   'KS',
#   '01',
#   '',
#   '',
#   '00',
#   '00',
#   '000',
#   ''],
#  ['', '7', '000000000000556815', '0015', '300', '', ''],
#  ['',
#   '',
#   '02-19-18     1',
#   '2018454054  03-13-18     1',
#   '28 0001 1776852297/70   NOT DELIVERED',
#   '',
#   ''],
#  ['', '', '', '', '28 0001 1776967817/70   NOT DELIVERED', '', ''],
#  ['', '', '', '', '28 0001 1776996691/70   NOT DELIVERED', '', ''],
#  ['', '', '', '', '28 0001 1777007557/70   NOT DELIVERED', '', ''],
#  ['', '', '', '', '28 0001 1777050459/70   NOT DELIVERED', '', ''],
#  ['', '', '', '', '28 0001 1777068402/70   NOT DELIVERED', '', ''],
#  ['', '', '', '', 'stored in  :          1 fr. 03-12-18', '', ''],
#  ['',
#   '80',
#   '',
#   '556815',
#   'Toothed b. axis EGC-120-2040-TB-KF',
#   '',
#   '',
#   'O2  1374107292   TRÜC',
#   'KS',
#   '01',
#   '',
#   '',
#   '00',
#   '00',
#   '000',
#   ''],
#  ['', '8', '000000000000556815', '0015', '300', '', ''],
#  ['',
#   '',
#   '02-19-18     1',
#   '2018454054  03-13-18     1',
#   '28 0001 1776852297/80   NOT DELIVERED',
#   '',
#   ''],
#  ['', '', '', '', '28 0001 1776967817/80   NOT DELIVERED', '', ''],
#  ['', '', '', '', '28 0001 1776996691/80   NOT DELIVERED', '', ''],
#  ['', '', '', '', '28 0001 1777007557/80   NOT DELIVERED', '', ''],
#  ['', '', '', '', '28 0001 1777050459/80   NOT DELIVERED', '', ''],
#  ['', '', '', '', '28 0001 1777068402/80   NOT DELIVERED', '', ''],
#  ['',
#   '90',
#   '',
#   '556815',
#   'Toothed b. axis EGC-120-1540-TB-KF',
#   '',
#   '',
#   'O2  1374107304   GLFT',
#   'KS',
#   '01',
#   '',
#   '',
#   '00',
#   '00',
#   '000',
#   ''],
#  ['', '9', '000000000000556815', '0015', '300', '', ''],
#  ['',
#   '',
#   '02-19-18     2',
#   '2018454054  03-13-18     2',
#   '28 0001 1776852297/90   NOT DELIVERED',
#   '',
#   ''],
#  ['', '', '', '', '28 0001 1776967817/90   NOT DELIVERED', '', ''],
#  ['',
#   '',
#   '',
#   '',
#   '28 0001 1776996691/90   03-13-18     2',
#   '20908611/130  03-13-18     2',
#   ''],
#  ['',
#   '100',
#   '',
#   '556815',
#   'Toothed b. axis EGC-120-2440-TB-KF',
#   '',
#   '',
#   'O2  1374107315   RÜCK',
#   'KS',
#   '01',
#   '',
#   '',
#   '00',
#   '00',
#   '000',
#   ''],
#  ['', '10', '000000000000556815', '0015', '300', '', ''],
#  ['',
#   '',
#   '02-19-18     2',
#   '2018454054  03-13-18     2',
#   '28 0001 1776852297/100  NOT DELIVERED',
#   '',
#   ''],
#  ['', '', '', '', '28 0001 1776967817/100  NOT DELIVERED', '', ''],
#  ['', '', '', '', '28 0001 1776996691/100  NOT DELIVERED', '', ''],
#  ['', '', '', '', '28 0001 1777007557/100  NOT DELIVERED', '', ''],
#  ['', '', '', '', '28 0001 1777050459/100  NOT DELIVERED', '', ''],
#  ['', '', '', '', '28 0001 1777068402/100  NOT DELIVERED', '', ''],
#  ['',
#   '110',
#   '',
#   '556815',
#   'Toothed b. axis EGC-120-2120-TB-KF',
#   '',
#   '',
#   'O2  1374107214   TRÜC',
#   'KS',
#   '01',
#   '',
#   '',
#   '00',
#   '00',
#   '000',
#   ''],
#  ['', '11', '000000000000556815', '0015', '300', '', ''],
#  ['',
#   '',
#   '02-19-18     4',
#   '2018454054  03-13-18     4',
#   '28 0001 1776852297/110  NOT DELIVERED',
#   '',
#   ''],
#  ['', '', '', '', '28 0001 1776967817/110  NOT DELIVERED', '', ''],
#  ['', '', '', '', '28 0001 1776996691/110  NOT DELIVERED', '', ''],
#  ['', '', '', '', '28 0001 1777007557/110  NOT DELIVERED', '', ''],
#  ['', '', '', '', '28 0001 1777050459/110  NOT DELIVERED', '', ''],
#  ['', '', '', '', '28 0001 1777068402/110  NOT DELIVERED', '', ''],
#  ['',
#   '130',
#   '',
#   '556815',
#   'Toothed b. axis EGC-120-1600-TB-KF',
#   '',
#   '',
#   'O2  1374107361   GLFT',
#   'KS',
#   '01',
#   '',
#   '',
#   '00',
#   '00',
#   '000',
#   ''],
#  ['', '13', '000000000000556815', '0015', '300', '', ''],
#  ['',
#   '',
#   '02-19-18     2',
#   '2018454054  03-13-18     2',
#   '28 0001 1776852297/130  NOT DELIVERED',
#   '',
#   ''],
#  ['', '', '', '', '28 0001 1776967817/130  NOT DELIVERED', '', ''],
#  ['', '', '', '', '28 0001 1776996691/130  NOT DELIVERED', '', ''],
#  ['', '', '', '', '28 0001 1777007557/130  NOT DELIVERED', '', ''],
#  ['', '', '', '', '28 0001 1777050459/130  NOT DELIVERED', '', ''],
#  ['',
#   '',
#   '',
#   '',
#   '28 0001 1777068402/130  03-15-18     2',
#   '20910375/170  03-15-18     2',
#   ''],
#  ['',
#   '140',
#   '',
#   '556820',
#   'Spindle axis    EGC-HD-160-    -BS',
#   '',
#   '',
#   'O2  1374107352   ERO',
#   'KC',
#   '01',
#   '',
#   '',
#   '00',
#   '00',
#   '000',
#   ''],
#  ['', '14', '000000000000556820', '0015', '300', '', ''],
#  ['', '', '02-19-18     2', '2018454054  04-05-18     2', '', '', ''],
#  ['',
#   '150',
#   '',
#   '556821',
#   'Spindle axis    EGC-HD-220-    -BS',
#   '',
#   '',
#   'O2  1374107427   ERO',
#   'KC',
#   '01',
#   '',
#   '',
#   '00',
#   '00',
#   '000',
#   ''],
#  ['', '15', '000000000000556821', '0015', '300', '', ''],
#  ['', '', '02-19-18     1', '2018454054  03-27-18     1', '', '', ''],
#  ['',
#   '160',
#   '',
#   '556821',
#   'Spindle axis    EGC-HD-220-    -BS',
#   '',
#   '',
#   'O2  1374106338   GLFT',
#   'KC',
#   '01',
#   '',
#   '',
#   '00',
#   '00',
#   '000',
#   ''],
#  ['', '16', '000000000000556821', '0015', '300', '', ''],
#  ['',
#   '',
#   '02-19-18    11',
#   '2018454054  03-13-18     5      M2',
#   '28 0001 1776852297/160  NOT DELIVERED',
#   '',
#   ''],
#  ['',
#   '',
#   '',
#   '2018454054  03-14-18     3',
#   '28 0001 1776967817/160  NOT DELIVERED',
#   '',
#   ''],
#  ['',
#   '',
#   '',
#   '2018454054  03-15-18     3',
#   '28 0001 1776996691/160  NOT DELIVERED',
#   '',
#   ''],
#  ['', '', '', '', '28 0001 1777007557/160  NOT DELIVERED', '', ''],
#  ['', '', '', '', '28 0001 1777050459/160  NOT DELIVERED', '', ''],
#  ['', '', '', '', '28 0001 1777068402/160  NOT DELIVERED', '', ''],
#  ['', '', '', '', 'stored in  :          2 fr. 03-12-18', '', ''],
#  ['', 'Ident-code', 'EGC-HD-220-350-BS-25P-0H-GP', '']]

# %%
df=[]
for i in range(1,len(items)) :
    part={}
    part['partno']=items[i][0][3]
    part['firstcfdate']=datetime.datetime.strptime(items[i][2][3].split()[1],  "%m-%d-%y")
    part['qty']=items[i][2][2].split()[1]
    part['so']=items[i][2][3].split()[0] + items[i][0][1]
    
    #status
    status = items[i][0][7]
    if status !='' :
        part['status']=status.split()[2] 
    
    dn=items[i][-1][4]
    part['dn']=dn
    
    #INVOICE
    invoice = items[i][-1][5]
    
    if invoice !='':
        part['iv']=invoice
        part['ivdate']=datetime.datetime.strptime(invoice.split()[1],  "%m-%d-%y")
        part['ivqty']=invoice.split()[2]
        part['etd']=part['ivdate'] + datetime.timedelta(days=7)
        
    else :
        part['etd'] = part['firstcfdate'] 
        
    if dn.count('stored') :
        print(dn)
        part['etd']=dn.split()[5]

    df.append(part)
    
    
    
DF=pd.DataFrame(df)
col=["so", "qty", "status", "firstcfdate","ivdate", "ivqty", 'etd', 'dn','iv']
DF[col]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-311-3f7eca5f88b4> in <module>()
#      37 DF=pd.DataFrame(df)
#      38 col=["so", "qty", "status", "firstcfdate","ivdate", "ivqty", 'etd', 'dn','iv']
# ---> 39 DF[col]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2131         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2132             # either boolean or fancy integer index
# -> 2133             return self._getitem_array(key)
#    2134         elif isinstance(key, DataFrame):
#    2135             return self._getitem_frame(key)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2175             return self._take(indexer, axis=0, convert=False)
#    2176         else:
# -> 2177             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2178             return self._take(indexer, axis=1, convert=True)
#    2179
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1267                 if mask.any():
#    1268                     raise KeyError('{mask} not in index'
# -> 1269                                    .format(mask=objarr[mask]))
#    1270
#    1271                 return _values_from_object(indexer)
#
# KeyError: "['so' 'qty' 'status' 'firstcfdate' 'ivdate' 'ivqty' 'etd' 'dn' 'iv'] not in index"

# %%
items[29][2][2]
# Out:
# '03-02-18    21'

# %%
dn
# Out:
# 'stored in  :          2 fr. 03-12-18'

# %%
toggle=False
items=[]

item={}

with open('text.txt',"r", encoding="UTF-8") as file:
    line=file.readline()
    if toggle:
        print ("toggle is on")
    while line!='':
        line=file.readline()
        #item no extraction
        if line.count("|") > 9:
                items.append(item)
                item={}
                item['itemno'] = line.split()[1]
                #print(item)

        if line.find(SO)!=-1 and line.find('Seite')==-1: 
                l=line.split()[1][1:]
                print("line", l)
                print(len(l))
                item['deliverydate']=l[1][1:]
                if len(l)==14 : 
                    item['delivernote']=l[7]
                    item['dnissued']=l[8]
                    item['invoice#']=l[10]
                    item['invoicedate']=l[11]
                    print(item)
        if line.find("NOT DELIVERED"):
                    toggle = True
                    continue
       
        
        
        if line.find("Ident-code"): 
                item['code']=line.split()
# Out:
# line ype
# 3
# line 02-19-18
# 8
# line 02-19-18
# 8
# line 02-19-18
# 8
# line 02-19-18
# 8
# line 02-19-18
# 8
# line 02-19-18
# 8
# line 02-19-18
# 8
# line 02-19-18
# 8
# line 02-19-18
# 8
# line 02-19-18
# 8
# line 02-19-18
# 8
# line 02-19-18
# 8
# line 02-19-18
# 8
# line 02-19-18
# 8
# line 02-19-18
# 8
# line 02-19-18
# 8
# line
# 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-161-6074d39b94b7> in <module>()
#      21                 print("line", l)
#      22                 print(len(l))
# ---> 23                 item['deliverydate']=l[1][1:]
#      24                 if len(l)==14 :
#      25                     item['delivernote']=l[7]
#
# IndexError: string index out of range

# %%
item=[]
items=[]

item={}


for idx, line in enumerate(lines[24:]):
    #item no extraction
    if line.count("|") > 9:
            items.append(item)
            item={}
            item['itemno'] = line.split()[1]
            #print(item)
            
    if line.find("Ident-code"): 
        print(line.split())
#             item['code']=line.split()[1][1:]
            
    if line.find(SO)!=-1 and line.find('Seite')==-1: 
            l=line.split()[1][1:]
            #print(l)
            #print(len(l))
            item['deliverydate']=l[1][1:]
            if len(l)==14 : 
                item['delivernote']=l[7]
                item['dnissued']=l[8]
                item['invoice#']=l[10]
                item['invoicedate']=l[11]
                #print(item)
# Out:
# ['|', '10', '|', '|', '574090|electric', 'drive', 'ESBF-...-63-150', '|', '|', '|X2', '1374107355', 'ERO', '|KC', '|01|', '|', '|00|00|000', '|']
# ['|', '1', '|000000000000574090', '|0015', '|300|', '|']
# ['|', '|02-19-18', '6|2018454054', '03-27-18', '6', '|', '|', '|']
# ['------------------------------------------------------------------------------------------------------------------------------------']
# ['---------------------------------------------------------------------------------------------------------']
# ['|Ident-code', '|ESBF-BS-63-150-25P', '|']
# ['---------------------------------------------------------------------------------------------------------']
# ['|Prod.Segm./Delivery', 'Clas|KC', '/', '4', '|']
# ['---------------------------------------------------------------------------------------------------------']
# ['------------------------------------------------------------------------------------------------------------------------------------']
# ['|', '20', '|', '|', '8024917|Toothed', 'b.', 'axis', 'ELGA-TB-KF-150-2900', '|', '|', '|O2', '1374107354', 'LOE', '|KS', '|01|', '|', '|00|00|000', '|']
# ['|', '2', '|000000000008024917', '|0015', '|300|', '|']
# ['|', '|02-19-18', '1|2018454054', '03-13-18', '1', '|28', '0001', '1776852297/20', '03-09-18', '1|', '20906945/10', '03-09-18', '1', '|']
# ['------------------------------------------------------------------------------------------------------------------------------------']
# ['---------------------------------------------------------------------------------------------------------']
# ['|Ident-code', '|ELGA-TB-KF-150-2900-0H', '|']
# ['---------------------------------------------------------------------------------------------------------']
# ['|Prod.Segm./Delivery', 'Clas|KS', '/', '4', '|']
# ['---------------------------------------------------------------------------------------------------------']
# ['11673701', 'Terminreklamation', 'fr.', '03-08-2018', '05:31:49', 'KR0JYHW', '03-08-2018', '08:14:40']
# ['------------------------------------------------------------------------------------------------------------------------------------']
# ['|', '30', '|', '|', '556809|Spindle', 'axis', 'EGC-120-220-BS-KF', '|', '|', '|O2', '1374107297', 'GLFT|KC', '|01|', '|', '|00|00|000', '|']
# ['|', '3', '|000000000000556809', '|0015', '|300|', '|']
# ['|', '|02-19-18', '1|2018454054', '03-13-18', '1', '|28', '0001', '1776852297/30', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1776967817/30', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1776996691/30', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1777007557/30', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1777050459/30', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1777068402/30', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|stored', 'in', ':', '1', 'fr.', '03-13-18|', '|']
# ['------------------------------------------------------------------------------------------------------------------------------------']
# ['---------------------------------------------------------------------------------------------------------']
# ['|Ident-code', '|EGC-120-220-BS-25P-KF-0H-MR-GP', '|']
# ['---------------------------------------------------------------------------------------------------------']
# ['|Prod.Segm./Delivery', 'Clas|KC', '/', '4', '|']
# ['---------------------------------------------------------------------------------------------------------']
# ['11673702', 'Terminreklamation', 'fr.', '03-08-2018', '05:31:57', 'KR0JYHW', '03-08-2018', '08:14:56']
# []
# []
# []
# []
# ['03-16-18', '05:55:14', 'KR0HSH', 'Order', 'overview', '2018454054', '(', 'by', 'EDI', 'FIP', '-', 'SAP', ')', 'Seite', '2']
# ['------------------------------------------------------------------------------------------------------------------------------------']
# ['------------------------------------------------------------------------------------------------------------------------------------']
# ['|', '40', '|', '|', '556815|Toothed', 'b.', 'axis', 'EGC-120-940-TB-KF', '|', '|', '|O2', '1374107225', 'LOE', '|KS', '|01|', '|', '|00|00|000', '|']
# ['|', '4', '|000000000000556815', '|0015', '|300|', '|']
# ['|', '|02-19-18', '1|2018454054', '03-13-18', '1', '|28', '0001', '1776852297/40', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1776967817/40', '03-12-18', '1|', '20907778/100', '03-12-18', '1', '|']
# ['------------------------------------------------------------------------------------------------------------------------------------']
# ['---------------------------------------------------------------------------------------------------------']
# ['|Ident-code', '|EGC-120-940-TB-KF-0H-GP', '|']
# ['---------------------------------------------------------------------------------------------------------']
# ['|Prod.Segm./Delivery', 'Clas|KS', '/', '4', '|']
# ['---------------------------------------------------------------------------------------------------------']
# ['11673703', 'Terminreklamation', 'fr.', '03-08-2018', '05:32:04', 'KR0JYHW', '03-08-2018', '08:14:50']
# ['------------------------------------------------------------------------------------------------------------------------------------']
# ['|', '50', '|', '|', '556815|Toothed', 'b.', 'axis', 'EGC-120-1440-TB-KF', '|', '|', '|O2', '1374107236', 'GLFT|KS', '|01|', '|', '|00|00|000', '|']
# ['|', '5', '|000000000000556815', '|0015', '|300|', '|']
# ['|', '|02-19-18', '1|2018454054', '03-13-18', '1', '|28', '0001', '1776852297/50', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1776967817/50', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1776996691/50', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1777007557/50', '03-13-18', '1|', '20908611/180', '03-13-18', '1', '|']
# ['------------------------------------------------------------------------------------------------------------------------------------']
# ['---------------------------------------------------------------------------------------------------------']
# ['|Ident-code', '|EGC-120-1440-TB-KF-0H-GP', '|']
# ['---------------------------------------------------------------------------------------------------------']
# ['|Prod.Segm./Delivery', 'Clas|KS', '/', '4', '|']
# ['---------------------------------------------------------------------------------------------------------']
# ['11673704', 'Terminreklamation', 'fr.', '03-08-2018', '05:32:11', 'KR0JYHW', '03-08-2018', '08:15:06']
# ['------------------------------------------------------------------------------------------------------------------------------------']
# ['|', '60', '|', '|', '556815|Toothed', 'b.', 'axis', 'EGC-120-1540-TB-KF', '|', '|', '|O2', '1374107269', 'GLFT|KS', '|01|', '|', '|00|00|000', '|']
# ['|', '6', '|000000000000556815', '|0015', '|300|', '|']
# ['|', '|02-19-18', '2|2018454054', '03-13-18', '2', '|28', '0001', '1776852297/60', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1776967817/60', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1776996691/60', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1777007557/60', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1777050459/60', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1777068402/60', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|stored', 'in', ':', '2', 'fr.', '03-12-18|', '|']
# ['------------------------------------------------------------------------------------------------------------------------------------']
# ['---------------------------------------------------------------------------------------------------------']
# ['|Ident-code', '|EGC-120-1540-TB-KF-0H-GP', '|']
# ['---------------------------------------------------------------------------------------------------------']
# ['|Prod.Segm./Delivery', 'Clas|KS', '/', '4', '|']
# ['---------------------------------------------------------------------------------------------------------']
# ['11673705', 'Terminreklamation', 'fr.', '03-08-2018', '05:32:18', 'KR0JYHW', '03-08-2018', '08:15:13']
# ['11676948', 'Terminreklamation', 'fr.', '03-15-2018', '05:19:27', 'KR0JYHW', '03-15-2018', '07:28:16']
# ['11677770', 'Terminreklamation', 'fr.', '03-16-2018', '05:25:13', 'KR0JYHW']
# ['------------------------------------------------------------------------------------------------------------------------------------']
# ['|', '70', '|', '|', '556815|Toothed', 'b.', 'axis', 'EGC-120-1040-TB-KF', '|', '|', '|O2', '1374107280', 'GLFT|KS', '|01|', '|', '|00|00|000', '|']
# ['|', '7', '|000000000000556815', '|0015', '|300|', '|']
# ['|', '|02-19-18', '1|2018454054', '03-13-18', '1', '|28', '0001', '1776852297/70', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1776967817/70', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1776996691/70', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1777007557/70', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1777050459/70', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1777068402/70', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|stored', 'in', ':', '1', 'fr.', '03-12-18|', '|']
# ['------------------------------------------------------------------------------------------------------------------------------------']
# ['---------------------------------------------------------------------------------------------------------']
# ['|Ident-code', '|EGC-120-1040-TB-KF-0H-GP', '|']
# ['---------------------------------------------------------------------------------------------------------']
# ['|Prod.Segm./Delivery', 'Clas|KS', '/', '4', '|']
# ['---------------------------------------------------------------------------------------------------------']
# ['11673706', 'Terminreklamation', 'fr.', '03-08-2018', '05:32:26', 'KR0JYHW', '03-08-2018', '08:15:20']
# ['11676949', 'Terminreklamation', 'fr.', '03-15-2018', '05:19:42', 'KR0JYHW', '03-15-2018', '07:28:22']
# ['03-16-18', '05:55:14', 'KR0HSH', 'Order', 'overview', '2018454054', '(', 'by', 'EDI', 'FIP', '-', 'SAP', ')', 'Seite', '3']
# ['------------------------------------------------------------------------------------------------------------------------------------']
# ['11677771', 'Terminreklamation', 'fr.', '03-16-2018', '05:25:22', 'KR0JYHW']
# ['------------------------------------------------------------------------------------------------------------------------------------']
# ['|', '80', '|', '|', '556815|Toothed', 'b.', 'axis', 'EGC-120-2040-TB-KF', '|', '|', '|O2', '1374107292', 'TRÜC|KS', '|01|', '|', '|00|00|000', '|']
# ['|', '8', '|000000000000556815', '|0015', '|300|', '|']
# ['|', '|02-19-18', '1|2018454054', '03-13-18', '1', '|28', '0001', '1776852297/80', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1776967817/80', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1776996691/80', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1777007557/80', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1777050459/80', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1777068402/80', 'NOT', 'DELIVERED', '|', '|']
# ['------------------------------------------------------------------------------------------------------------------------------------']
# ['---------------------------------------------------------------------------------------------------------']
# ['|Ident-code', '|EGC-120-2040-TB-KF-0H-GP', '|']
# ['---------------------------------------------------------------------------------------------------------']
# ['|Prod.Segm./Delivery', 'Clas|KS', '/', '4', '|']
# ['---------------------------------------------------------------------------------------------------------']
# ['11673707', 'Terminreklamation', 'fr.', '03-08-2018', '05:32:32', 'KR0JYHW', '03-08-2018', '08:15:26']
# ['11676970', 'Terminreklamation', 'fr.', '03-15-2018', '05:19:56', 'KR0JYHW', '03-15-2018', '07:28:32']
# ['------------------------------------------------------------------------------------------------------------------------------------']
# ['|', '90', '|', '|', '556815|Toothed', 'b.', 'axis', 'EGC-120-1540-TB-KF', '|', '|', '|O2', '1374107304', 'GLFT|KS', '|01|', '|', '|00|00|000', '|']
# ['|', '9', '|000000000000556815', '|0015', '|300|', '|']
# ['|', '|02-19-18', '2|2018454054', '03-13-18', '2', '|28', '0001', '1776852297/90', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1776967817/90', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1776996691/90', '03-13-18', '2|', '20908611/130', '03-13-18', '2', '|']
# ['------------------------------------------------------------------------------------------------------------------------------------']
# ['---------------------------------------------------------------------------------------------------------']
# ['|Ident-code', '|EGC-120-1540-TB-KF-0H-GP', '|']
# ['---------------------------------------------------------------------------------------------------------']
# ['|Prod.Segm./Delivery', 'Clas|KS', '/', '4', '|']
# ['---------------------------------------------------------------------------------------------------------']
# ['11673708', 'Terminreklamation', 'fr.', '03-08-2018', '05:32:41', 'KR0JYHW', '03-08-2018', '08:15:32']
# ['------------------------------------------------------------------------------------------------------------------------------------']
# ['|', '100', '|', '|', '556815|Toothed', 'b.', 'axis', 'EGC-120-2440-TB-KF', '|', '|', '|O2', '1374107315', 'RÜCK|KS', '|01|', '|', '|00|00|000', '|']
# ['|', '10', '|000000000000556815', '|0015', '|300|', '|']
# ['|', '|02-19-18', '2|2018454054', '03-13-18', '2', '|28', '0001', '1776852297/100', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1776967817/100', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1776996691/100', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1777007557/100', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1777050459/100', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1777068402/100', 'NOT', 'DELIVERED', '|', '|']
# ['------------------------------------------------------------------------------------------------------------------------------------']
# ['---------------------------------------------------------------------------------------------------------']
# ['|Ident-code', '|EGC-120-2440-TB-KF-0H-GP-KL', '|']
# ['---------------------------------------------------------------------------------------------------------']
# ['|Prod.Segm./Delivery', 'Clas|KS', '/', '4', '|']
# ['---------------------------------------------------------------------------------------------------------']
# ['11673709', 'Terminreklamation', 'fr.', '03-08-2018', '05:32:49', 'KR0JYHW', '03-08-2018', '08:15:41']
# ['------------------------------------------------------------------------------------------------------------------------------------']
# ['|', '110', '|', '|', '556815|Toothed', 'b.', 'axis', 'EGC-120-2120-TB-KF', '|', '|', '|O2', '1374107214', 'TRÜC|KS', '|01|', '|', '|00|00|000', '|']
# ['|', '11', '|000000000000556815', '|0015', '|300|', '|']
# ['|', '|02-19-18', '4|2018454054', '03-13-18', '4', '|28', '0001', '1776852297/110', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1776967817/110', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1776996691/110', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1777007557/110', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1777050459/110', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1777068402/110', 'NOT', 'DELIVERED', '|', '|']
# ['------------------------------------------------------------------------------------------------------------------------------------']
# ['---------------------------------------------------------------------------------------------------------']
# ['|Ident-code', '|EGC-120-2120-TB-KF-0H-GP-KL-KR', '|']
# ['---------------------------------------------------------------------------------------------------------']
# ['|Prod.Segm./Delivery', 'Clas|KS', '/', '4', '|']
# ['---------------------------------------------------------------------------------------------------------']
# ['11673710', 'Terminreklamation', 'fr.', '03-08-2018', '05:32:55', 'KR0JYHW', '03-08-2018', '08:15:47']
# ['03-16-18', '05:55:14', 'KR0HSH', 'Order', 'overview', '2018454054', '(', 'by', 'EDI', 'FIP', '-', 'SAP', ')', 'Seite', '4']
# ['------------------------------------------------------------------------------------------------------------------------------------']
# ['------------------------------------------------------------------------------------------------------------------------------------']
# ['|', '120', '|', '|', '556815|Toothed', 'b.', 'axis', 'EGC-120-1200-TB-KF', '|', '|', '|O2', '1374107346', 'GLFT|KS', '|01|', '|', '|00|00|000', '|']
# ['|', '12', '|000000000000556815', '|0015', '|300|', '|']
# ['|', '|02-19-18', '2|2018454054', '03-13-18', '2', '|28', '0001', '1776852297/120', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1776967817/120', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1776996691/120', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1777007557/120', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1777050459/120', '03-15-18', '2|', '20910355/30', '03-15-18', '2', '|']
# ['------------------------------------------------------------------------------------------------------------------------------------']
# ['---------------------------------------------------------------------------------------------------------']
# ['|Ident-code', '|EGC-120-1200-TB-KF-0H-GP', '|']
# ['---------------------------------------------------------------------------------------------------------']
# ['|Prod.Segm./Delivery', 'Clas|KS', '/', '4', '|']
# ['---------------------------------------------------------------------------------------------------------']
# ['11673711', 'Terminreklamation', 'fr.', '03-08-2018', '05:33:05', 'KR0JYHW', '03-08-2018', '08:15:52']
# ['------------------------------------------------------------------------------------------------------------------------------------']
# ['|', '130', '|', '|', '556815|Toothed', 'b.', 'axis', 'EGC-120-1600-TB-KF', '|', '|', '|O2', '1374107361', 'GLFT|KS', '|01|', '|', '|00|00|000', '|']
# ['|', '13', '|000000000000556815', '|0015', '|300|', '|']
# ['|', '|02-19-18', '2|2018454054', '03-13-18', '2', '|28', '0001', '1776852297/130', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1776967817/130', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1776996691/130', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1777007557/130', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1777050459/130', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|', '|28', '0001', '1777068402/130', '03-15-18', '2|', '20910375/170', '03-15-18', '2', '|']
# ['------------------------------------------------------------------------------------------------------------------------------------']
# ['---------------------------------------------------------------------------------------------------------']
# ['|Ident-code', '|EGC-120-1600-TB-KF-0H-GP', '|']
# ['---------------------------------------------------------------------------------------------------------']
# ['|Prod.Segm./Delivery', 'Clas|KS', '/', '4', '|']
# ['---------------------------------------------------------------------------------------------------------']
# ['11673712', 'Terminreklamation', 'fr.', '03-08-2018', '05:33:14', 'KR0JYHW', '03-08-2018', '08:16:00']
# ['------------------------------------------------------------------------------------------------------------------------------------']
# ['|', '140', '|', '|', '556820|Spindle', 'axis', 'EGC-HD-160-', '-BS', '|', '|', '|O2', '1374107352', 'ERO', '|KC', '|01|', '|', '|00|00|000', '|']
# ['|', '14', '|000000000000556820', '|0015', '|300|', '|']
# ['|', '|02-19-18', '2|2018454054', '04-05-18', '2', '|', '|', '|']
# ['------------------------------------------------------------------------------------------------------------------------------------']
# ['---------------------------------------------------------------------------------------------------------']
# ['|Ident-code', '|EGC-HD-160-400-BS-20P-0H-GP', '|']
# ['---------------------------------------------------------------------------------------------------------']
# ['|Prod.Segm./Delivery', 'Clas|KC', '/', '9', '|']
# ['---------------------------------------------------------------------------------------------------------']
# ['------------------------------------------------------------------------------------------------------------------------------------']
# ['|', '150', '|', '|', '556821|Spindle', 'axis', 'EGC-HD-220-', '-BS', '|', '|', '|O2', '1374107427', 'ERO', '|KC', '|01|', '|', '|00|00|000', '|']
# ['|', '15', '|000000000000556821', '|0015', '|300|', '|']
# ['|', '|02-19-18', '1|2018454054', '03-27-18', '1', '|', '|', '|']
# ['------------------------------------------------------------------------------------------------------------------------------------']
# ['---------------------------------------------------------------------------------------------------------']
# ['|Ident-code', '|EGC-HD-220-400-BS-25P-0H-GP', '|']
# ['---------------------------------------------------------------------------------------------------------']
# ['|Prod.Segm./Delivery', 'Clas|KC', '/', '9', '|']
# ['---------------------------------------------------------------------------------------------------------']
# ['------------------------------------------------------------------------------------------------------------------------------------']
# ['|', '160', '|', '|', '556821|Spindle', 'axis', 'EGC-HD-220-', '-BS', '|', '|', '|O2', '1374106338', 'GLFT|KC', '|01|', '|', '|00|00|000', '|']
# ['|', '16', '|000000000000556821', '|0015', '|300|', '|']
# ['|', '|02-19-18', '11|2018454054', '03-13-18', '5', 'M2|28', '0001', '1776852297/160', 'NOT', 'DELIVERED', '|', '|']
# ['|', '|', '|2018454054', '03-14-18', '3', '|28', '0001', '1776967817/160', 'NOT', 'DELIVERED', '|', '|']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-133-43cdb6a159c5> in <module>()
#      21             #print(l)
#      22             #print(len(l))
# ---> 23             item['deliverydate']=l[1][1:]
#      24             if len(l)==14 :
#      25                 item['delivernote']=l[7]
#
# IndexError: string index out of range

# %%
items[2]
# Out:
# {'delivernote': '1776852297/20',
#  'deliverydate': '02-19-18',
#  'dnissued': '03-09-18',
#  'invoice#': '20906945/10',
#  'invoicedate': '03-09-18',
#  'itemno': '20'}

# %%
items
# Out:
# [[],
#  ['10'],
#  ['20', ['20906945/10']],
#  ['30'],
#  ['40'],
#  ['50'],
#  ['60'],
#  ['70'],
#  ['80'],
#  ['90'],
#  ['100'],
#  ['110'],
#  ['120'],
#  ['130'],
#  ['140'],
#  ['150'],
#  ['160'],
#  ['170'],
#  ['180'],
#  ['190'],
#  ['200'],
#  ['210'],
#  ['220'],
#  ['230'],
#  ['240'],
#  ['250'],
#  ['260'],
#  ['270'],
#  ['280', ['20898555/150']],
#  ['290', ['20898555/160'], ['20908611/160']]]

# %%
for i in range(6):
    f.readline()

line=f.readline().split()
SO=line[5]

for

# %%
SO
# Out:
# '2018454054'

# %%
print(f.readline())
# Out:
# ===> PRIO 200

# %%
#Read Excel file 
exl=pd.read_excel('Book1.xlsx', converters={'item#':str,'part#':str, 'deliverydate':pd.to_datetime})
#https://stackoverflow.com/questions/32591466/python-pandas-how-to-specify-data-types-when-reading-an-excel-file

# %%
lines= f.readlines()

# %%
parse_flag=False
total=[]

for i in lines:
    if i[0]=='-':
        parse_flag=True
        continue
    if parse_flag==True and i[0]=='|':
        
        line=i.split()
        item=line[1];  so=line[2];
        newdate=datetime.datetime.strptime(line[3],  "%Y-%m-%d")
       
        delta=(newdate-datetime.datetime.now()).days
        
        single=[item, so, newdate, delta]
        total.append(single)
        parse_flag=False
    
df=pd.DataFrame(total)

# %%
#ID created for comparision and merge
df['id']=df[1] + df[0]
exl['id']=exl['part#'] + exl['item#']

# %%
kk=df.merge(exl)

# %%
kk['delta']=kk['deliverydate'] - kk[2]

# %%
#To save excel file 
writer=pd.ExcelWriter('output.xlsx')
kk.to_excel(writer,'Sheet1')
writer.save()
